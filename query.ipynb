# %%
import json
from typing import List, Dict, Optional, Tuple
import time
from shapely.geometry import Polygon, Point
import overpy
import os

# %%
with open("bariCoordinates.json") as f:
    COORDINATES = json.load(f)

# %%
# commented were not found
AMENITIES = {
    # # Food & Drink
    # 'bar': 'Establishments selling alcoholic drinks with vibrant atmosphere',
    # 'pub': 'Traditional establishments with alcoholic drinks and food',
    # # 'restaurant': 'Places serving meals with seating',
    # 'cafe': 'Informal places serving beverages and light meals',
    # 'fast_food': 'Quick service food establishments',
    # # 'biergarten': 'Outdoor beer gardens',
    'ice_cream': 'Ice cream parlors',
    'food_court': 'Areas with multiple food vendors',
    # # Entertainment & Nightlife
    'nightclub': 'Places for dancing and drinking at night',
    # # 'social_club': 'Member-only social establishments',
    # 'casino': 'Gambling establishments',
    # 'cinema': 'Movie theaters',
    # #### ADDED
    # 'arts_centre': 'Venues for various arts performances',
    # 'music_venue': 'Indoor venues for live contemporary music',
    # # 'community_centre': 'Community centers for local events',
    # # 'social_centre': 'Places for free and not-for-profit activities',
    'events_venue': 'Buildings specifically for organizing events',
    # 'marketplace': 'Public marketplaces for daily or weekly trading',
    # # 'place_of_worship': 'Churches, mosques, temples and other religious buildings',
    # # 'monastery': 'Monasteries and religious living quarters',
    'internet_cafe': 'Cafes providing internet access',
}

# %%
API = overpy.Overpass()

# %%
def create_polygon(coordinates: List) -> Polygon:
    """Create a Polygon from coordinates."""
    polygon = Polygon(coordinates)
    return polygon

# %%
def get_polygon_coords_string(polygon: Polygon) -> str:
    """Convert polygon coordinates to Overpass API polygon format."""
    coords = list(polygon.exterior.coords)
    
    # Convert to Overpass polygon format: "lat1 lon1 lat2 lon2 lat3 lon3 ..."
    coord_pairs = []
    for lon, lat in coords:
        coord_pairs.extend([str(lat), str(lon)])
    
    polygon_string = " ".join(coord_pairs)
    return polygon_string

# %%
def point_in_polygon(polygon: Polygon, lat: float, lon: float) -> bool:
    """Check if a point is within the polygon."""
    point = Point(lon, lat)
    return polygon.contains(point)

# %%
def is_handled_tag(tag_key: str) -> bool:
    """Check if a tag is already handled in the structured extraction."""
    handled_prefixes = [
        'name', 'alt_name', 'official_name', 'short_name', 'loc_name', 'old_name',
        'addr:', 'contact:', 'phone', 'email', 'website', 'facebook', 'instagram',
        'opening_hours', 'cuisine', 'diet:', 'outdoor_seating', 'wheelchair', 
        'internet_access', 'smoking', 'takeaway', 'delivery', 'capacity',
        'description', 'operator', 'brand', 'building', 'level', 'indoor',
        'fee', 'charge', 'payment:', 'accepted_cards', 'cash',
        'air_conditioning', 'heating', 'reservation', 'dress_code',
        'min_age', 'max_age', 'toilets', 'baby_feeding', 'changing_table',
        'parking', 'bicycle_parking', 'drive_through', 'drive_in',
        'amenity'
    ]
    
    for prefix in handled_prefixes:
        if tag_key.startswith(prefix) or tag_key == prefix.rstrip(':'):
            return True
    
    return False

# %%
def extract_address(tags: Dict) -> Optional[Dict]:
    """Extract comprehensive address information."""
    address = {}
    address_keys = {
        'addr:street': 'street',
        'addr:housenumber': 'housenumber',
        'addr:housename': 'housename',
        'addr:postcode': 'postcode',
        'addr:city': 'city',
        'addr:country': 'country',
        'addr:state': 'state',
        'addr:province': 'province',
        'addr:district': 'district',
        'addr:suburb': 'suburb',
        'addr:hamlet': 'hamlet',
        'addr:place': 'place',
        'addr:unit': 'unit',
        'addr:floor': 'floor',
        'addr:door': 'door',
        'addr:full': 'full_address'
    }
    
    for osm_key, clean_key in address_keys.items():
        if osm_key in tags:
            address[clean_key] = tags[osm_key]
    
    return address if address else None

def extract_contact_info(tags: Dict) -> Optional[Dict]:
    """Extract contact information."""
    contact = {}
    contact_keys = [
        'phone', 'mobile', 'fax', 'email', 'website', 'url',
        'contact:phone', 'contact:mobile', 'contact:fax', 'contact:email', 
        'contact:website', 'contact:facebook', 'contact:instagram', 
        'contact:twitter', 'contact:youtube', 'facebook', 'instagram'
    ]
    
    for key in contact_keys:
        if key in tags:
            clean_key = key.replace('contact:', '')
            contact[clean_key] = tags[key]
    
    return contact if contact else None

def extract_business_info(tags: Dict) -> Optional[Dict]:
    """Extract business operating information."""
    business = {}
    business_keys = [
        'opening_hours', 'opening_hours:drive_through', 'opening_hours:kitchen',
        'operator', 'owner', 'ref', 'source', 'start_date', 'end_date',
        'description', 'note', 'fixme', 'capacity', 'stars', 'rooms'
    ]
    
    for key in business_keys:
        if key in tags:
            business[key] = tags[key]
    
    return business if business else None

def extract_accessibility_info(tags: Dict) -> Optional[Dict]:
    """Extract accessibility information."""
    accessibility = {}
    accessibility_keys = [
        'wheelchair', 'wheelchair:description', 'blind', 'deaf',
        'level', 'elevator', 'ramp', 'tactile_paving',
        'step_count', 'handrail', 'width', 'door:width'
    ]
    
    for key in accessibility_keys:
        if key in tags:
            accessibility[key] = tags[key]
    
    return accessibility if accessibility else None


def extract_food_drink_info(tags: Dict) -> Optional[Dict]:
    """Extract food and drink specific information."""
    food_drink = {}
    
    # Cuisine and dietary information
    cuisine_keys = ['cuisine', 'drink', 'brewery', 'microbrewery']
    
    # Dietary restrictions and options
    diet_keys = [k for k in tags.keys() if k.startswith('diet:')]
    
    # Service types
    service_keys = [
        'outdoor_seating', 'takeaway', 'delivery', 'drive_through', 'drive_in',
        'reservation', 'smoking', 'bar', 'restaurant', 'self_service',
        'breakfast', 'lunch', 'dinner', 'happy_hour'
    ]
    
    all_food_keys = cuisine_keys + diet_keys + service_keys
    
    for key in all_food_keys:
        if key in tags:
            food_drink[key] = tags[key]
    
    return food_drink if food_drink else None


def extract_location_info(tags: Dict) -> Optional[Dict]:
    """Extract location and building information."""
    location = {}
    location_keys = [
        'building', 'building:levels', 'building:material', 'building:colour',
        'level', 'indoor', 'room', 'location', 'addr:floor',
        'roof:shape', 'roof:material', 'roof:colour', 'height'
    ]
    
    for key in location_keys:
        if key in tags:
            location[key] = tags[key]
    
    return location if location else None


def extract_entertainment_info(tags: Dict) -> Optional[Dict]:
    """Extract entertainment specific information."""
    entertainment = {}
    entertainment_keys = [
        'dance:teaching', 'dance:style', 'music:genre', 'live_music',
        'karaoke', 'dj', 'game', 'gambling', 'adult', 'min_age', 'max_age',
        'dress_code', 'entrance_fee', 'show', 'performance',
        'screen', 'projection', '3d', 'imax'
    ]
    
    for key in entertainment_keys:
        if key in tags:
            entertainment[key] = tags[key]
    
    return entertainment if entertainment else None


def extract_payment_info(tags: Dict) -> Optional[Dict]:
    """Extract payment and pricing information."""
    payment = {}
    
    # Payment methods
    payment_keys = [k for k in tags.keys() if k.startswith('payment:')]
    
    # Pricing
    pricing_keys = [
        'fee', 'charge', 'price', 'cost', 'toll', 'entrance_fee',
        'membership_fee', 'accepted_cards', 'cash'
    ]
    
    all_payment_keys = payment_keys + pricing_keys
    
    for key in all_payment_keys:
        if key in tags:
            payment[key] = tags[key]
    
    return payment if payment else None


def extract_services_info(tags: Dict) -> Optional[Dict]:
    """Extract additional services and facilities."""
    services = {}
    services_keys = [
        'internet_access', 'internet_access:fee', 'internet_access:ssid',
        'wifi', 'computer', 'atm', 'toilets', 'baby_feeding', 'changing_table',
        'shower', 'lockers', 'lost_property', 'luggage_storage',
        'parking', 'parking:fee', 'bicycle_parking', 'motorcycle_parking',
        'air_conditioning', 'heating', 'fireplace', 'garden', 'terrace',
        'balcony', 'playground', 'dog', 'pets_allowed', 'service',
        'self_service', 'full_service', 'valet', 'cloakroom'
    ]
    
    for key in services_keys:
        if key in tags:
            services[key] = tags[key]
    
    return services if services else None

# %%
def extract_amenity_info(osm_object, obj_type: str, 
                        lat: Optional[float] = None, 
                        lon: Optional[float] = None) -> Dict:
    """Extract comprehensive information from an OSM object."""
    # Get coordinates
    if obj_type == 'node':
        coordinates = {'lat': float(osm_object.lat), 'lon': float(osm_object.lon)}
    else:
        coordinates = {'lat': lat, 'lon': lon} if lat and lon else None
    
    amenity_info = {
        'osm_id': osm_object.id,
        'osm_type': obj_type,
        'coordinates': coordinates,
        
        # Basic identification
        'name': osm_object.tags.get('name', None),
        'amenity': osm_object.tags.get('amenity'),
        
        # Alternative names
        'alt_name': osm_object.tags.get('alt_name'),
        'official_name': osm_object.tags.get('official_name'),
        'short_name': osm_object.tags.get('short_name'),
        'local_name': osm_object.tags.get('loc_name'),
        'old_name': osm_object.tags.get('old_name'),
        'brand': osm_object.tags.get('brand'),
        
        # Structured information
        'address': extract_address(osm_object.tags),
        'contact': extract_contact_info(osm_object.tags),
        'business_info': extract_business_info(osm_object.tags),
        'accessibility': extract_accessibility_info(osm_object.tags),
        'food_drink': extract_food_drink_info(osm_object.tags),
        'location_info': extract_location_info(osm_object.tags),
        'entertainment': extract_entertainment_info(osm_object.tags),
        'payment': extract_payment_info(osm_object.tags),
        'services': extract_services_info(osm_object.tags),
        
        # All other tags
        'other_tags': {k: v for k, v in osm_object.tags.items() 
                      if not is_handled_tag(k)}
    }
    
    return amenity_info

# %%
def build_overpass_query(amenity_type: str, polygon_coords_string: str) -> str:
    """Build Overpass API query for a specific amenity type."""
    return f"""
    [out:json][timeout:60];
    (
      node["amenity"="{amenity_type}"](poly:"{polygon_coords_string}");
      way["amenity"="{amenity_type}"](poly:"{polygon_coords_string}");
      relation["amenity"="{amenity_type}"](poly:"{polygon_coords_string}");
    );
    out center meta;
    """

# %%
def process_way_center(way) -> Optional[Tuple[float, float]]:
    """Calculate center coordinates for a way object."""
    if hasattr(way, 'center_lat') and hasattr(way, 'center_lon'):
        return float(way.center_lat), float(way.center_lon)
    elif hasattr(way, 'nodes') and way.nodes:
        total_lat = sum(float(node.lat) for node in way.nodes)
        total_lon = sum(float(node.lon) for node in way.nodes)
        return total_lat / len(way.nodes), total_lon / len(way.nodes)
    elif hasattr(way, 'nd') and way.nd:
        total_lat = sum(float(node.lat) for node in way.nd)
        total_lon = sum(float(node.lon) for node in way.nd)
        return total_lat / len(way.nd), total_lon / len(way.nd)
    return None


def process_relation_center(relation) -> Optional[Tuple[float, float]]:
    """Find center coordinates for a relation object."""
    if hasattr(relation, 'center_lat') and hasattr(relation, 'center_lon'):
        return float(relation.center_lat), float(relation.center_lon)
    elif hasattr(relation, 'members') and relation.members:
        for member in relation.members:
            if hasattr(member, 'lat') and hasattr(member, 'lon'):
                return float(member.lat), float(member.lon)
    return None

# %%
def query_amenity(api: overpy.Overpass, amenity_type: str, 
                 polygon_coords_string: str) -> List[Dict]:
    """Query OSM for a specific amenity type within a polygon."""
    if not polygon_coords_string:
        print("Error: No polygon coordinates available")
        return []
    
    overpass_query = build_overpass_query(amenity_type, polygon_coords_string)
    
    try:
        print(f"Querying {amenity_type} within custom polygon...")
        result = api.query(overpass_query)
        
        amenities = []
        
        # Process nodes
        for node in result.nodes:
            amenity_info = extract_amenity_info(node, 'node')
            amenities.append(amenity_info)
        
        # Process ways
        for way in result.ways:
            center = process_way_center(way)
            if center:
                center_lat, center_lon = center
                amenity_info = extract_amenity_info(way, 'way', center_lat, center_lon)
                amenities.append(amenity_info)
        
        # Process relations
        for relation in result.relations:
            center = process_relation_center(relation)
            if center:
                center_lat, center_lon = center
                amenity_info = extract_amenity_info(relation, 'relation', center_lat, center_lon)
                amenities.append(amenity_info)
        
        print(f"✅ Found {len(amenities)} {amenity_type}(s) in custom polygon area")
        return amenities
        
    except Exception as e:
        print(f"❌ Error querying {amenity_type}: {e}")
        print(f"   This might be due to:")
        print(f"   - High server load (try again later)")
        print(f"   - Network connectivity issues")
        print(f"   - Overpass API timeout")
        print(f"   - Invalid polygon coordinates")
        return []

# %%
def save_to_json(amenities: List[Dict], amenity_type: str, 
                polygon: Polygon, filename: Optional[str] = None):
    """Save amenity data to a JSON file."""
    summary = {
        'query_info': {
            'amenity_type': amenity_type,
            'total_found': len(amenities),
            'query_timestamp': time.strftime("%Y-%m-%d %H:%M:%S"),
            'polygon_bounds': polygon.bounds if polygon else None
        },
        'amenities': amenities
    }
    
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(summary, f, indent=2, ensure_ascii=False)
        print(f"✅ {len(amenities)} {amenity_type}(s) with detailed info saved to {filename}")
    except Exception as e:
        print(f"❌ Error saving {amenity_type} data: {e}")

# %%
def find_all_amenities(coordinates: List, amenities_dict: Dict, 
                      api: overpy.Overpass, searchIfAlreadyFound = False, delay: int = 2):
    """Find all amenities in the specified polygon area."""
    print("🔍 Finding amenities with comprehensive details in custom polygon area...")
    print("=" * 80)
    
    # Create polygon
    polygon = create_polygon(coordinates)
    polygon_coords_string = get_polygon_coords_string(polygon)
    
    print(f"📍 Polygon area: ~{polygon.area * 111000 * 111000:.0f} square meters")
    print(f"🔎 Searching for {len(amenities_dict)} amenity types with detailed tags...")
    print("-" * 50)
    
    total_found = 0
    
    for amenity_type, description in amenities_dict.items():
        print(f"\n🔎 Searching for {amenity_type}: {description}")
        filename = f"custom_area_{amenity_type}s_detailed.json"
        if searchIfAlreadyFound or not os.path.exists(filename):
            amenities = query_amenity(api, amenity_type, polygon_coords_string)
            
            if amenities:
                save_to_json(amenities, amenity_type, polygon, filename)
                total_found += len(amenities)
            else:
                print(f"   No {amenity_type}s found in this polygon area")
            
            # Be respectful to the API
            time.sleep(delay)
    
    print("\n" + "=" * 80)
    print(f"🎉 Total amenities found: {total_found}")
    print(f"📁 Created detailed JSON files for each amenity type")
    print("💡 Files contain comprehensive OSM tag information")
    print("📊 Each file includes query metadata and structured data")

# %%
find_all_amenities(COORDINATES, AMENITIES, API, True)
# Out:
# 🔍 Finding amenities with comprehensive details in custom polygon area...
# ================================================================================
# 📍 Polygon area: ~154441969 square meters
# 🔎 Searching for 5 amenity types with detailed tags...
# --------------------------------------------------
#
# 🔎 Searching for ice_cream: Ice cream parlors
# Querying ice_cream within custom polygon...
# ✅ Found 12 ice_cream(s) in custom polygon area
# ✅ 12 ice_cream(s) with detailed info saved to custom_area_ice_creams_detailed.json
#
# 🔎 Searching for food_court: Areas with multiple food vendors
# Querying food_court within custom polygon...
# ✅ Found 1 food_court(s) in custom polygon area
# ✅ 1 food_court(s) with detailed info saved to custom_area_food_courts_detailed.json
#
# 🔎 Searching for nightclub: Places for dancing and drinking at night
# Querying nightclub within custom polygon...
# ✅ Found 3 nightclub(s) in custom polygon area
# ✅ 3 nightclub(s) with detailed info saved to custom_area_nightclubs_detailed.json
#
# 🔎 Searching for events_venue: Buildings specifically for organizing events
# Querying events_venue within custom polygon...
# ✅ Found 12 events_venue(s) in custom polygon area
# ✅ 12 events_venue(s) with detailed info saved to custom_area_events_venues_detailed.json
#
# 🔎 Searching for internet_cafe: Cafes providing internet access
# Querying internet_cafe within custom polygon...
# ✅ Found 1 internet_cafe(s) in custom polygon area
# ✅ 1 internet_cafe(s) with detailed info saved to custom_area_internet_cafes_detailed.json
#
# ================================================================================
# 🎉 Total amenities found: 29
# 📁 Created detailed JSON files for each amenity type
# 💡 Files contain comprehensive OSM tag information
# 📊 Each file includes query metadata and structured data

# %%
otherKeys = []
result = []
for file in os.listdir(os.getcwd()):
    if file.startswith("custom_area"):
        with open(file, encoding='utf-8') as f:
            queryResult = json.load(f)

        category = " ".join(queryResult["query_info"]["amenity_type"].split("_"))

        for amenity in queryResult["amenities"]:
            out = {
                "Spazio": amenity["name"],
                "Categoria": category,
                "latitudine": amenity["coordinates"]["lat"],
                "longitudine": amenity["coordinates"]["lon"]
            }
            
            for k in amenity:
                if (k not in ["name", "amenity", "coordinates", "osm_type", "other_tags", "osm_id", "official_name", "payment", "food_drink"]):
                    if amenity[k] is not None:
                        if k not in otherKeys:
                            otherKeys.append(k) 
                        if isinstance(amenity[k], str):
                            out[k] = amenity[k]
                        elif isinstance(amenity[k], dict):
                            out[k] = " ".join([str(v) for v in amenity[k].values()])
                        
            result.append(out)

# %%
otherKeys, result
# Out:
# (['accessibility',
#   'address',
#   'contact',
#   'business_info',
#   'location_info',
#   'services',
#   'alt_name',
#   'brand',
#   'old_name',
#   'entertainment'],
#  [{'Spazio': 'Spaccabari',
#    'Categoria': 'arts centre',
#    'latitudine': 41.1282103,
#    'longitudine': 16.8728567,
#    'accessibility': 'no'},
#   {'Spazio': 'BLUorg',
#    'Categoria': 'arts centre',
#    'latitudine': 41.121101,
#    'longitudine': 16.8756672},
#   {'Spazio': 'Spazio 13',
#    'Categoria': 'arts centre',
#    'latitudine': 41.1246725,
#    'longitudine': 16.8560676,
#    'address': 'Via Colonello de Cristoforis 8 70123 Bari',
#    'contact': 'https://spazio13.org',
#    'business_info': 'Mo-Fr 10:00-20:00',
#    'accessibility': 'yes'},
#   {'Spazio': "Ipogeo Dell'Arte",
#    'Categoria': 'arts centre',
#    'latitudine': 41.1626943,
#    'longitudine': 16.7482118,
#    'address': 'Via Pisa 4 70127 Santo Spirito',
#    'contact': 'https://www.leonardobasile.it/index.htm',
#    'accessibility': 'no -1',
#    'location_info': '-1'},
#   {'Spazio': 'Spazio Murat',
#    'Categoria': 'arts centre',
#    'latitudine': 41.1264879,
#    'longitudine': 16.8717015,
#    'address': 'Piazza del Ferrarese 70121 Bari',
#    'contact': 'https://www.spaziomurat.it/',
#    'accessibility': 'yes',
#    'location_info': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1150636,
#    'longitudine': 16.8729563,
#    'address': 'Largo Ignazio Ciaia Bari'},
#   {'Spazio': 'Nineli Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1157215,
#    'longitudine': 16.8724899,
#    'contact': '+39 389 1904207',
#    'business_info': 'Biscardi Tommaso'},
#   {'Spazio': 'Brasserie',
#    'Categoria': 'cafe',
#    'latitudine': 41.1168191,
#    'longitudine': 16.8706075},
#   {'Spazio': 'Gianton Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1167908,
#    'longitudine': 16.8719666,
#    'business_info': 'Mo-Fr 05:00-18:30; Sa 05:00-13:30'},
#   {'Spazio': 'Bar Gambrinus',
#    'Categoria': 'cafe',
#    'latitudine': 41.116415,
#    'longitudine': 16.8723823},
#   {'Spazio': 'C House Bakery Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1179176,
#    'longitudine': 16.8697059,
#    'address': 'Piazza Aldo Moro',
#    'business_info': 'Mo-Sa 06:00-19:00; Su 07:00-19:00 C House',
#    'accessibility': 'yes'},
#   {'Spazio': 'Bar Bari Nord',
#    'Categoria': 'cafe',
#    'latitudine': 41.1183307,
#    'longitudine': 16.8690945},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1104966,
#    'longitudine': 16.8748874},
#   {'Spazio': 'Gran Caffé Catullo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1190185,
#    'longitudine': 16.871027,
#    'address': '24 70122 Bari Piazza Aldo Moro',
#    'business_info': 'Catullo Services s.r.l.'},
#   {'Spazio': 'Caffè Barucchelli',
#    'Categoria': 'cafe',
#    'latitudine': 41.1268934,
#    'longitudine': 16.8717079,
#    'address': 'Piazza del Ferrarese 3 70122 Bari',
#    'business_info': 'Roberto Vergari survey',
#    'accessibility': 'yes',
#    'services': 'yes'},
#   {'Spazio': 'Il Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1114833,
#    'longitudine': 16.8621615},
#   {'Spazio': 'Cabiria',
#    'Categoria': 'cafe',
#    'latitudine': 41.0930037,
#    'longitudine': 16.8610398},
#   {'Spazio': 'Bar Lucarelli',
#    'Categoria': 'cafe',
#    'latitudine': 41.0930012,
#    'longitudine': 16.8596865},
#   {'Spazio': 'Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.073593,
#    'longitudine': 16.8573504,
#    'business_info': 'closed',
#    'services': 'no'},
#   {'Spazio': 'Catullo il Fondatore',
#    'Categoria': 'cafe',
#    'latitudine': 41.1147165,
#    'longitudine': 16.8730931,
#    'address': "Viale Unità d'Italia 51,53 70124",
#    'contact': '+39 080 5565766',
#    'business_info': 'GEPA s.r.l.'},
#   {'Spazio': 'Millennium Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1032928,
#    'longitudine': 16.8865371},
#   {'Spazio': 'Bar Williams',
#    'Categoria': 'cafe',
#    'latitudine': 41.1031238,
#    'longitudine': 16.8605107,
#    'address': 'Via Arcidiacono Giovanni'},
#   {'Spazio': 'Bar Moderno',
#    'Categoria': 'cafe',
#    'latitudine': 41.1036764,
#    'longitudine': 16.859842,
#    'business_info': 'Vito Scalera'},
#   {'Spazio': 'Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.073812,
#    'longitudine': 16.8638138},
#   {'Spazio': 'Voltaire',
#    'Categoria': 'cafe',
#    'latitudine': 41.0972279,
#    'longitudine': 16.8552724,
#    'services': 'wlan no'},
#   {'Spazio': 'Bar Tolesco',
#    'Categoria': 'cafe',
#    'latitudine': 41.121313,
#    'longitudine': 16.8672357,
#    'accessibility': 'yes'},
#   {'Spazio': 'Bar Fly',
#    'Categoria': 'cafe',
#    'latitudine': 41.1076272,
#    'longitudine': 16.8775018,
#    'services': 'wlan'},
#   {'Spazio': 'Abbaticchio',
#    'Categoria': 'cafe',
#    'latitudine': 41.106656,
#    'longitudine': 16.8837894},
#   {'Spazio': "Bar Dell'Angolo",
#    'Categoria': 'cafe',
#    'latitudine': 41.1053341,
#    'longitudine': 16.8596273,
#    'address': 'Viale Papa Pio Dodicesimo 1A 70124 Bari'},
#   {'Spazio': 'Bar Campus',
#    'Categoria': 'cafe',
#    'latitudine': 41.1102972,
#    'longitudine': 16.8798752,
#    'contact': '+39 080 5520722',
#    'business_info': 'Gestioni Sud s.r.l.',
#    'services': 'no'},
#   {'Spazio': 'Bar Olimpia',
#    'Categoria': 'cafe',
#    'latitudine': 41.119508,
#    'longitudine': 16.882098,
#    'business_info': 'Mo-Fr 06:30-20:00; Sa,Su 06:30-13:30'},
#   {'Spazio': 'Qui si gode',
#    'Categoria': 'cafe',
#    'latitudine': 41.1642128,
#    'longitudine': 16.7484709,
#    'address': 'Lungomare Cristoforo Colombo 172/A 70127 Bari',
#    'contact': '+39 080 5337267',
#    'business_info': 'Florio Michele',
#    'accessibility': 'no',
#    'services': 'yes'},
#   {'Spazio': 'Parkway Bikers Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.111209,
#    'longitudine': 16.8528645,
#    'alt_name': 'Bikers Cafè',
#    'address': 'Viale Louis Pasteur 12/14 70124 Bari',
#    'contact': 'https://www.facebook.com/pages/Parkway-Bikers-Caf%C3%A8-Bari/232259998286',
#    'business_info': 'https://www.facebook.com/pages/Parkway-Bikers-Caf%C3%A8-Bari/232259998286'},
#   {'Spazio': 'Caffè Luna',
#    'Categoria': 'cafe',
#    'latitudine': 41.1046604,
#    'longitudine': 16.8784428,
#    'alt_name': 'Cristian',
#    'address': 'Via Stefano Jacini',
#    'services': 'no'},
#   {'Spazio': 'Givarò',
#    'Categoria': 'cafe',
#    'latitudine': 41.1041172,
#    'longitudine': 16.8826903},
#   {'Spazio': 'Caffè Crème',
#    'Categoria': 'cafe',
#    'latitudine': 41.0969173,
#    'longitudine': 16.8546634},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1237493,
#    'longitudine': 16.8292829},
#   {'Spazio': 'Etoile Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1000219,
#    'longitudine': 16.8675662,
#    'address': 'Via Giulio Petroni'},
#   {'Spazio': 'Nuviani',
#    'Categoria': 'cafe',
#    'latitudine': 41.1000992,
#    'longitudine': 16.885056},
#   {'Spazio': 'Jamboree',
#    'Categoria': 'cafe',
#    'latitudine': 41.1010779,
#    'longitudine': 16.8798792},
#   {'Spazio': 'San Marco Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1057023,
#    'longitudine': 16.9192843,
#    'address': 'Via Salvatore Quasimodo 1 70126 Bari'},
#   {'Spazio': 'Bar Luciana',
#    'Categoria': 'cafe',
#    'latitudine': 41.1139411,
#    'longitudine': 16.8965056},
#   {'Spazio': 'Bar Saicaf',
#    'Categoria': 'cafe',
#    'latitudine': 41.1150657,
#    'longitudine': 16.8940673},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1158134,
#    'longitudine': 16.8915353},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1162355,
#    'longitudine': 16.8904549},
#   {'Spazio': 'Max Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1160902,
#    'longitudine': 16.8902479},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1122722,
#    'longitudine': 16.8954451},
#   {'Spazio': 'Bar Miss Italia',
#    'Categoria': 'cafe',
#    'latitudine': 41.1002459,
#    'longitudine': 16.8643234},
#   {'Spazio': 'Bar Ateneo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1211126,
#    'longitudine': 16.8684867,
#    'business_info': 'Angelo Alizzi',
#    'accessibility': 'yes'},
#   {'Spazio': 'Hagakure Momi',
#    'Categoria': 'cafe',
#    'latitudine': 41.1216734,
#    'longitudine': 16.8684744,
#    'address': 'Via Roberto da Bari 146 70121 Bari',
#    'contact': 'https://hagakuremomi.com/',
#    'business_info': 'Mo-Sa 12:00-23:00; Su 12:00-15:00, 19:00-23:00'},
#   {'Spazio': 'Bar MAX CAFE',
#    'Categoria': 'cafe',
#    'latitudine': 41.1152944,
#    'longitudine': 16.8188631},
#   {'Spazio': 'Caffè Fiore',
#    'Categoria': 'cafe',
#    'latitudine': 41.1266395,
#    'longitudine': 16.8474268,
#    'address': 'Via Tommaso Fiore 25 Bari',
#    'contact': '+39 080 5793582',
#    'business_info': 'Francesco Del Carmelo survey'},
#   {'Spazio': 'Gelateria Caffetteria Re Vittorio',
#    'Categoria': 'cafe',
#    'latitudine': 41.1263307,
#    'longitudine': 16.8691548,
#    'address': 'Corso Vittorio Emanuele Secondo 89 70122 Bari',
#    'accessibility': 'no'},
#   {'Spazio': 'Bar degli Amici',
#    'Categoria': 'cafe',
#    'latitudine': 41.1025173,
#    'longitudine': 16.8849299,
#    'services': 'no'},
#   {'Spazio': 'Jo&Le - interporto',
#    'Categoria': 'cafe',
#    'latitudine': 41.131696,
#    'longitudine': 16.8088181,
#    'address': 'Viale Giuseppe Degennaro 1 70132 Bari'},
#   {'Spazio': 'Caffè Greco',
#    'Categoria': 'cafe',
#    'latitudine': 41.103811,
#    'longitudine': 16.8791842},
#   {'Spazio': 'Telebari',
#    'Categoria': 'cafe',
#    'latitudine': 41.1043526,
#    'longitudine': 16.8787953,
#    'address': 'Via Giuseppe Fanelli 221c',
#    'business_info': 'Scaramuzzi S.A.S.'},
#   {'Spazio': "Diamond's",
#    'Categoria': 'cafe',
#    'latitudine': 41.1150733,
#    'longitudine': 16.8750577,
#    'address': 'Via Giuseppe Re David'},
#   {'Spazio': 'Bar Lucy',
#    'Categoria': 'cafe',
#    'latitudine': 41.113739,
#    'longitudine': 16.8766497},
#   {'Spazio': "Nero Perla Cafe'",
#    'Categoria': 'cafe',
#    'latitudine': 41.1167342,
#    'longitudine': 16.8538589,
#    'contact': '+39 0802021632',
#    'business_info': 'F.lli Stramaglia s.n.c.'},
#   {'Spazio': 'Bar Isabella',
#    'Categoria': 'cafe',
#    'latitudine': 41.1125622,
#    'longitudine': 16.8706217,
#    'address': 'Via Buccari 105',
#    'business_info': 'Cosimo De Lucia',
#    'accessibility': 'yes'},
#   {'Spazio': 'Caffé Fortunato',
#    'Categoria': 'cafe',
#    'latitudine': 41.1196555,
#    'longitudine': 16.8676128,
#    'address': 'Via Scipione Crisanzio 40 70122 Bari'},
#   {'Spazio': 'Caricola',
#    'Categoria': 'cafe',
#    'latitudine': 41.1197417,
#    'longitudine': 16.8690281,
#    'address': 'Via Scipione Crisanzio 2 70122 Bari'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1031109,
#    'longitudine': 16.8805157},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1067028,
#    'longitudine': 16.873424},
#   {'Spazio': 'Mavi bistrot',
#    'Categoria': 'cafe',
#    'latitudine': 41.1165321,
#    'longitudine': 16.8684778},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1323878,
#    'longitudine': 16.8668559},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1329499,
#    'longitudine': 16.8487233},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1326226,
#    'longitudine': 16.8496507},
#   {'Spazio': 'Coffee In',
#    'Categoria': 'cafe',
#    'latitudine': 41.107279,
#    'longitudine': 16.8750414,
#    'address': 'Viale Giuseppe di Vittorio 61 70125 Bari',
#    'business_info': 'Mo-Sa 03:40-18:40'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1175081,
#    'longitudine': 16.8793631},
#   {'Spazio': 'Full Coffee Time',
#    'Categoria': 'cafe',
#    'latitudine': 41.1239691,
#    'longitudine': 16.8573512,
#    'address': 'Via Francesco Crispi'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1241378,
#    'longitudine': 16.8572955},
#   {'Spazio': 'Bar Municipio',
#    'Categoria': 'cafe',
#    'latitudine': 41.1256098,
#    'longitudine': 16.8678681,
#    'address': 'Corso Vittorio Emanuele 84 Palazzo di Cittá 70122 Bari',
#    'business_info': 'Matteo Laraspata',
#    'accessibility': 'limited',
#    'services': 'no no no yes'},
#   {'Spazio': 'Tam Tam',
#    'Categoria': 'cafe',
#    'latitudine': 41.1258183,
#    'longitudine': 16.8680951,
#    'address': 'Corso Vittorio Emanuele Secondo 80 70122 Bari',
#    'contact': 'info@tamtambar.it https://www.tamtambar.it/',
#    'business_info': 'Arcangelo Filograno'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1187661,
#    'longitudine': 16.8676862},
#   {'Spazio': 'Caffè Perulli',
#    'Categoria': 'cafe',
#    'latitudine': 41.1185007,
#    'longitudine': 16.8846091,
#    'address': 'Corso Sidney Sonnino 140e 70121 Bari'},
#   {'Spazio': 'Il Faraone Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1011157,
#    'longitudine': 16.8885925,
#    'address': 'Via Giovanni Amendola 172b Bari',
#    'contact': '+39 080 9909346',
#    'business_info': 'Anaclerio Nicola'},
#   {'Spazio': 'Caffé Cognetti',
#    'Categoria': 'cafe',
#    'latitudine': 41.1231035,
#    'longitudine': 16.8731996,
#    'address': 'Via Salvatore Cognetti 19 70121 Bari',
#    'contact': 'https://www.caffecognetti.com/'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1253011,
#    'longitudine': 16.8595567,
#    'accessibility': 'no'},
#   {'Spazio': 'deCanto',
#    'Categoria': 'cafe',
#    'latitudine': 41.1341134,
#    'longitudine': 16.7634552,
#    'business_info': 'Lagardére Food Services srl',
#    'accessibility': '1',
#    'location_info': '1'},
#   {'Spazio': 'Brown Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.0426052,
#    'longitudine': 16.8517022,
#    'address': 'Via Umberto Minervini 17 70129 Bari',
#    'contact': '+39 328 55 41107',
#    'business_info': 'Dominique Cioce survey',
#    'accessibility': 'yes',
#    'services': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1178794,
#    'longitudine': 16.8646867},
#   {'Spazio': 'Dipierro Caffetteria',
#    'Categoria': 'cafe',
#    'latitudine': 41.1164573,
#    'longitudine': 16.8625482,
#    'address': 'Viale Ennio Quinto 1',
#    'contact': '3299222043'},
#   {'Spazio': 'FAL Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1185568,
#    'longitudine': 16.8690464,
#    'address': 'Piazza Aldo Moro Bari'},
#   {'Spazio': 'Gaudì Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1186722,
#    'longitudine': 16.8678322,
#    'address': 'Corso Italia 19D 70123 Bari',
#    'contact': '+39 3476224264',
#    'business_info': 'Mario De Carolis'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.0857856,
#    'longitudine': 16.8866601},
#   {'Spazio': 'Barbatrucco',
#    'Categoria': 'cafe',
#    'latitudine': 41.0845935,
#    'longitudine': 16.8630719},
#   {'Spazio': 'Caffetteria Etoile',
#    'Categoria': 'cafe',
#    'latitudine': 41.1185418,
#    'longitudine': 16.8875544,
#    'business_info': 'Mo-Fr 06:00-22:00'},
#   {'Spazio': 'Vintage Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1203157,
#    'longitudine': 16.8655783,
#    'address': 'Via de Rossi 189 70122 Bari'},
#   {'Spazio': "Caffetteria dell'angolo",
#    'Categoria': 'cafe',
#    'latitudine': 41.1204639,
#    'longitudine': 16.8658029},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1204634,
#    'longitudine': 16.8655757},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1204782,
#    'longitudine': 16.8660434},
#   {'Spazio': 'Il Dolcetto',
#    'Categoria': 'cafe',
#    'latitudine': 41.1213153,
#    'longitudine': 16.8657304,
#    'address': 'Via de Rossi'},
#   {'Spazio': 'Caffetteria Vanny e Mary',
#    'Categoria': 'cafe',
#    'latitudine': 41.1285419,
#    'longitudine': 16.8679317,
#    'accessibility': 'no'},
#   {'Spazio': 'Tavli Cafe',
#    'Categoria': 'cafe',
#    'latitudine': 41.1270854,
#    'longitudine': 16.8695879,
#    'accessibility': 'limited'},
#   {'Spazio': 'Caffetteria Cervezeria De La Plaza',
#    'Categoria': 'cafe',
#    'latitudine': 41.1287721,
#    'longitudine': 16.8687121},
#   {'Spazio': 'Bar San Nicola',
#    'Categoria': 'cafe',
#    'latitudine': 41.1305886,
#    'longitudine': 16.8694066,
#    'accessibility': 'limited'},
#   {'Spazio': 'Avamposto',
#    'Categoria': 'cafe',
#    'latitudine': 41.119595,
#    'longitudine': 16.8692962,
#    'address': 'Via Raffaele de Cesare 8A 70122 Bari',
#    'contact': 'http://www.avamposto.net',
#    'services': 'wlan'},
#   {'Spazio': 'Miramare',
#    'Categoria': 'cafe',
#    'latitudine': 41.1290735,
#    'longitudine': 16.8721362,
#    'accessibility': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1024789,
#    'longitudine': 16.8685406},
#   {'Spazio': 'Paloma Blanca Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1135953,
#    'longitudine': 16.8795487,
#    'address': 'Via Gaetano Postiglione 17 70126 Bari'},
#   {'Spazio': 'bar 900',
#    'Categoria': 'cafe',
#    'latitudine': 41.1209668,
#    'longitudine': 16.8613267,
#    'address': 'Via Alessandro Manzoni 158'},
#   {'Spazio': 'Gocce di Caffé',
#    'Categoria': 'cafe',
#    'latitudine': 41.1512892,
#    'longitudine': 16.7584409,
#    'contact': 'https://www.facebook.com/Gocce-Di-Caff%C3%A8-1728496227425363/'},
#   {'Spazio': 'Kimera',
#    'Categoria': 'cafe',
#    'latitudine': 41.1513898,
#    'longitudine': 16.7635691},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.126713,
#    'longitudine': 16.8605637,
#    'business_info': 'name, etc.',
#    'accessibility': 'no'},
#   {'Spazio': 'Sidney Caffe',
#    'Categoria': 'cafe',
#    'latitudine': 41.1213433,
#    'longitudine': 16.8677512,
#    'address': 'Via Domenico Nicolai 31',
#    'contact': 'https://www.facebook.com/sidneycaffebari/'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.0909536,
#    'longitudine': 16.8875525},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1180104,
#    'longitudine': 16.8643311},
#   {'Spazio': 'FUN Cafe',
#    'Categoria': 'cafe',
#    'latitudine': 41.1131451,
#    'longitudine': 16.8723057},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1155434,
#    'longitudine': 16.8730417},
#   {'Spazio': "Caffè L'arabica",
#    'Categoria': 'cafe',
#    'latitudine': 41.1268116,
#    'longitudine': 16.8596326,
#    'accessibility': 'limited'},
#   {'Spazio': 'New Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1261274,
#    'longitudine': 16.8608235,
#    'accessibility': 'no'},
#   {'Spazio': 'Antica Pasticceria del Liceo',
#    'Categoria': 'cafe',
#    'latitudine': 41.126822,
#    'longitudine': 16.860589,
#    'accessibility': 'no'},
#   {'Spazio': 'Carducci Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1273968,
#    'longitudine': 16.8640095,
#    'address': 'Via Giosuè Carducci 27 70122 Bari',
#    'contact': '+39 0805235396',
#    'accessibility': 'no'},
#   {'Spazio': 'Gran Caffè IN',
#    'Categoria': 'cafe',
#    'latitudine': 41.1242864,
#    'longitudine': 16.8614077,
#    'address': 'Via Abate Giacinto Gimma 259 70122 Bari',
#    'accessibility': 'no'},
#   {'Spazio': 'Visconti 25',
#    'Categoria': 'cafe',
#    'latitudine': 41.1241845,
#    'longitudine': 16.8629372,
#    'address': 'Via Sagarriga Visconti 25 70122 Bari',
#    'accessibility': 'yes'},
#   {'Spazio': 'B-5 Caffè & bistrot',
#    'Categoria': 'cafe',
#    'latitudine': 41.1254079,
#    'longitudine': 16.8650865,
#    'accessibility': 'no'},
#   {'Spazio': 'Caffè Cavour',
#    'Categoria': 'cafe',
#    'latitudine': 41.1218206,
#    'longitudine': 16.8722731,
#    'address': 'Corso Cavour 135 70121 Bari'},
#   {'Spazio': 'La Madia - Gran Caffè Saicaf',
#    'Categoria': 'cafe',
#    'latitudine': 41.1222636,
#    'longitudine': 16.8722248,
#    'address': 'Corso Cavour 121 70121 Bari',
#    'contact': '+39 0808178414',
#    'accessibility': 'yes'},
#   {'Spazio': 'Café Lucarelli',
#    'Categoria': 'cafe',
#    'latitudine': 41.1245577,
#    'longitudine': 16.8719584,
#    'address': 'Corso Cavour 49 70121 Bari',
#    'contact': '+39 0805232874 https://cafelucarelli.it/cafe-lucarelli-corso-cavour/'},
#   {'Spazio': 'Caffetteria Cavour',
#    'Categoria': 'cafe',
#    'latitudine': 41.1198823,
#    'longitudine': 16.8728425,
#    'address': 'Corso Cavour 138 70121 Bari IT Bari',
#    'business_info': '4:00-19:30'},
#   {'Spazio': 'Caffetteria Medici',
#    'Categoria': 'cafe',
#    'latitudine': 41.1182672,
#    'longitudine': 16.8730296,
#    'address': 'Corso Cavour 206 70121 Bari IT Bari',
#    'accessibility': 'no'},
#   {'Spazio': "Caffè D'Arte",
#    'Categoria': 'cafe',
#    'latitudine': 41.1272394,
#    'longitudine': 16.865289,
#    'address': "Via San Francesco d'Assisi 11 70122 Bari",
#    'contact': '+39 0805289368 https://caffedarte.eatbu.com/',
#    'services': 'yes'},
#   {'Spazio': 'Claus',
#    'Categoria': 'cafe',
#    'latitudine': 41.1259817,
#    'longitudine': 16.8660311,
#    'address': 'Corso Vittorio Emanuele Secondo 135 70122 Bari'},
#   {'Spazio': 'Caffè Borghese',
#    'Categoria': 'cafe',
#    'latitudine': 41.1256327,
#    'longitudine': 16.8650654,
#    'address': 'Corso Vittorio Emanuele Secondo 122 70122 Bari',
#    'business_info': 'Tu-Su 08:00-24:00'},
#   {'Spazio': 'Osteria Cafe',
#    'Categoria': 'cafe',
#    'latitudine': 41.1291955,
#    'longitudine': 16.8714208},
#   {'Spazio': 'Porto Franco',
#    'Categoria': 'cafe',
#    'latitudine': 41.1642436,
#    'longitudine': 16.7526402,
#    'address': 'Largo Cristoforo Colombo 15 70127 Santo Spirito',
#    'accessibility': '0',
#    'location_info': '0'},
#   {'Spazio': 'Coffee Morning',
#    'Categoria': 'cafe',
#    'latitudine': 41.1088861,
#    'longitudine': 16.8676226,
#    'address': 'Via Giulio Petroni 63/d 70124 Bari',
#    'accessibility': '0',
#    'location_info': '0'},
#   {'Spazio': 'Caffetteria Umberto',
#    'Categoria': 'cafe',
#    'latitudine': 41.1485115,
#    'longitudine': 16.7372369,
#    'address': 'Via della Lealtà 42/1 70127 Bari',
#    'contact': '080 533 5125'},
#   {'Spazio': 'Martinucci',
#    'Categoria': 'cafe',
#    'latitudine': 41.1279116,
#    'longitudine': 16.871926,
#    'address': 'Piazza Mercantile',
#    'accessibility': 'limited',
#    'services': 'yes yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1287266,
#    'longitudine': 16.8683804},
#   {'Spazio': 'Stanza Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1311431,
#    'longitudine': 16.8688994,
#    'brand': 'Veronero',
#    'contact': '+39 080 9147879',
#    'business_info': '2011',
#    'accessibility': 'no',
#    'services': 'wlan no'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1304085,
#    'longitudine': 16.8692625},
#   {'Spazio': "L'Allegrezza",
#    'Categoria': 'cafe',
#    'latitudine': 41.1302711,
#    'longitudine': 16.8692844},
#   {'Spazio': 'Barriera del Levante',
#    'Categoria': 'cafe',
#    'latitudine': 41.1368246,
#    'longitudine': 16.8662944,
#    'accessibility': 'no',
#    'services': 'no'},
#   {'Spazio': 'Antico Café del Carmine 1931',
#    'Categoria': 'cafe',
#    'latitudine': 41.1291414,
#    'longitudine': 16.8691418},
#   {'Spazio': 'Pescobar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1233298,
#    'longitudine': 16.8768208,
#    'address': 'Lungomare Araldo di Crollalanza 5 70121'},
#   {'Spazio': "Caffè dell'Accademia",
#    'Categoria': 'cafe',
#    'latitudine': 41.1308671,
#    'longitudine': 16.8705533,
#    'address': 'Strada Vanese 70122 Bari',
#    'accessibility': 'limited',
#    'services': 'wlan'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1143235,
#    'longitudine': 16.8795704},
#   {'Spazio': 'Latino',
#    'Categoria': 'cafe',
#    'latitudine': 41.1140305,
#    'longitudine': 16.8805682},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1182912,
#    'longitudine': 16.8690093,
#    'accessibility': '-1',
#    'location_info': '-1'},
#   {'Spazio': 'Peroni',
#    'Categoria': 'cafe',
#    'latitudine': 41.1180402,
#    'longitudine': 16.8708743,
#    'accessibility': 'yes'},
#   {'Spazio': 'Jérôme Chocolat',
#    'Categoria': 'cafe',
#    'latitudine': 41.1201313,
#    'longitudine': 16.872464,
#    'address': 'Corso Cavour 195A 70121 Bari',
#    'contact': 'https://jerome-chocolat.restauflow.it/store/bari',
#    'accessibility': 'limited'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1095145,
#    'longitudine': 16.8737058},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1067493,
#    'longitudine': 16.8472254},
#   {'Spazio': 'Nespresso',
#    'Categoria': 'cafe',
#    'latitudine': 41.1214819,
#    'longitudine': 16.8698878,
#    'brand': 'Nespresso',
#    'address': 'Via Sparano da Bari 156 70121 Bari',
#    'business_info': 'Mo-Fr 09:30-20:00; Sa 09:30-20:30; Su 10:00-13:15,16:30-20:00 Nespresso',
#    'accessibility': 'yes'},
#   {'Spazio': 'Artemisia',
#    'Categoria': 'cafe',
#    'latitudine': 41.158707,
#    'longitudine': 16.7495677,
#    'address': 'Corso Umberto I 57 70127 Bari IT Palese',
#    'contact': '+39 080 524 6972 info@artemisiabari.it https://www.artemisiabari.it/',
#    'business_info': 'Cooperativa Sociale Artes a.r.l.'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.090531,
#    'longitudine': 16.8890722},
#   {'Spazio': 'Sidney',
#    'Categoria': 'cafe',
#    'latitudine': 41.0961244,
#    'longitudine': 16.835343},
#   {'Spazio': 'Un Posto al Sole',
#    'Categoria': 'cafe',
#    'latitudine': 41.1601002,
#    'longitudine': 16.7631458,
#    'address': 'Via Tenente Saverio Noviello 2 70128',
#    'business_info': 'Valentina Caldarulo Il bar del Lido Moretti ha un nome diverso da lido'},
#   {'Spazio': 'La Trulleria, Peroni Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1346766,
#    'longitudine': 16.7640495,
#    'address': 'Bari',
#    'contact': 'info@mychef.it',
#    'business_info': 'MyChef Ristorante Comm. S.p.A.',
#    'accessibility': 'yes',
#    'services': 'wlan no yes'},
#   {'Spazio': 'Caffe Bellini',
#    'Categoria': 'cafe',
#    'latitudine': 41.1235626,
#    'longitudine': 16.8714622,
#    'address': 'Via Nicolò Putignani 19 70121 Bari',
#    'contact': '+39 0805247022',
#    'services': 'wlan'},
#   {'Spazio': 'Bar Stallone',
#    'Categoria': 'cafe',
#    'latitudine': 41.1239135,
#    'longitudine': 16.8533555,
#    'address': 'Via Michele Mirenghi 35 70123 Bari',
#    'contact': '0805740865 https://restaurantguru.it/BAR-Stallone-di-Stallone-Ignazio-Bari',
#    'business_info': 'Mo-Fr 08:00-20:00',
#    'services': 'yes'},
#   {'Spazio': 'Conviviale',
#    'Categoria': 'cafe',
#    'latitudine': 41.1131612,
#    'longitudine': 16.8761047,
#    'address': 'Via Giuseppe Re David 171 70125 Bari',
#    'contact': '+39  393 122 1988',
#    'business_info': 'Mo-Sa 06:30-20:00'},
#   {'Spazio': 'Baba Yaga',
#    'Categoria': 'cafe',
#    'latitudine': 41.1636941,
#    'longitudine': 16.7490123,
#    'address': 'Lungomare Cristoforo Colombo 154 70127 Bari',
#    'contact': '+39 080 533 1437',
#    'business_info': 'Mo-Su 06:00-00:45'},
#   {'Spazio': 'Pasticceria Rex',
#    'Categoria': 'cafe',
#    'latitudine': 41.1255887,
#    'longitudine': 16.8642946,
#    'address': 'Corso Vittorio Emanuele Secondo 146 70122 Bari',
#    'contact': '+39 0805232296 pasticceriarex@tiscali.it',
#    'business_info': 'Mo-Sa 06:30-20:30; We off; Su 06:30-14:00'},
#   {'Spazio': 'Sweet Coffee Bean',
#    'Categoria': 'cafe',
#    'latitudine': 41.1256108,
#    'longitudine': 16.8646783,
#    'address': 'Corso Vittorio Emanuele Secondo 134 70122 Bari',
#    'contact': '+39 0806450713',
#    'business_info': 'Mo-Sa 06:30-20:30'},
#   {'Spazio': 'Caffetteria Pizzuto',
#    'Categoria': 'cafe',
#    'latitudine': 41.124892,
#    'longitudine': 16.8653981,
#    'address': 'Via de Rossi 28 70122 Bari',
#    'contact': '+39 0805214141',
#    'business_info': 'Mo-Sa 06:30-18:30'},
#   {'Spazio': 'Mokador',
#    'Categoria': 'cafe',
#    'latitudine': 41.1221339,
#    'longitudine': 16.8728576,
#    'address': 'Corso Cavour 56 70121 Bari',
#    'contact': '+3913355308',
#    'business_info': 'Mo-Su 07:00-00:00',
#    'accessibility': 'limited'},
#   {'Spazio': 'Caffè Italiano',
#    'Categoria': 'cafe',
#    'latitudine': 41.1203094,
#    'longitudine': 16.8728012,
#    'address': 'Corso Cavour 126 70121 Bari IT'},
#   {'Spazio': 'Salvatore Petriella - Pasticceria Café & Bistrot',
#    'Categoria': 'cafe',
#    'latitudine': 41.1233424,
#    'longitudine': 16.8731527,
#    'address': 'Via Salvatore Cognetti 22 70121 Bari',
#    'contact': '+39 080 864 1410 https://www.salvatorepetriella.it',
#    'business_info': 'Mo-Su 07:00-21:30; PH closed Petriella Salvatore',
#    'accessibility': 'limited 0',
#    'location_info': '0',
#    'services': 'yes'},
#   {'Spazio': 'Colibrio',
#    'Categoria': 'cafe',
#    'latitudine': 41.1264539,
#    'longitudine': 16.8703801,
#    'address': 'Corso Vittorio Emanuele Secondo 47 70122 Bari',
#    'contact': '+39 080 917 9912;+39 375 548 8463',
#    'accessibility': 'no',
#    'services': 'yes'},
#   {'Spazio': 'Cavour 23 - Caffè Vergnano',
#    'Categoria': 'cafe',
#    'latitudine': 41.1253748,
#    'longitudine': 16.8718677,
#    'address': 'Via Niccolò Piccinni 23 70122 Bari',
#    'contact': '+39 0809671169',
#    'accessibility': 'limited',
#    'services': 'yes'},
#   {'Spazio': 'Crema & Cioccolato',
#    'Categoria': 'cafe',
#    'latitudine': 41.1202182,
#    'longitudine': 16.874029,
#    'address': 'Via Nicola de Giosa 94'},
#   {'Spazio': 'Caffè Big Ben',
#    'Categoria': 'cafe',
#    'latitudine': 41.1233234,
#    'longitudine': 16.8641392,
#    'address': 'Via Quintino Sella 75 70122 Bari',
#    'contact': '+39 0805227668'},
#   {'Spazio': 'Caffè Sospeso',
#    'Categoria': 'cafe',
#    'latitudine': 41.1264405,
#    'longitudine': 16.8474654},
#   {'Spazio': 'Caffè Moravia',
#    'Categoria': 'cafe',
#    'latitudine': 41.1227278,
#    'longitudine': 16.8693012,
#    'address': 'Via Principe Amedeo 63 70121 Bari'},
#   {'Spazio': 'Starbucks',
#    'Categoria': 'cafe',
#    'latitudine': 41.1225391,
#    'longitudine': 16.8706769,
#    'brand': 'Starbucks',
#    'address': 'Via Argiro 112 70121 Bari',
#    'contact': 'https://www.starbucks.it/',
#    'business_info': '07:00-21:00',
#    'accessibility': 'limited'},
#   {'Spazio': 'Bistrot 21',
#    'Categoria': 'cafe',
#    'latitudine': 41.1161784,
#    'longitudine': 16.8723505},
#   {'Spazio': 'Giuvì',
#    'Categoria': 'cafe',
#    'latitudine': 41.1244724,
#    'longitudine': 16.8744347,
#    'address': 'Via Sabino Fiorese',
#    'services': 'yes'},
#   {'Spazio': 'Cavaliere',
#    'Categoria': 'cafe',
#    'latitudine': 41.1222297,
#    'longitudine': 16.8522147},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.0986502,
#    'longitudine': 16.828504,
#    'business_info': 'Mo-Sa 09:00-21:00; Su 10:00-21:00',
#    'accessibility': 'yes 0',
#    'location_info': '0',
#    'services': 'yes'},
#   {'Spazio': 'Sidney caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.0975454,
#    'longitudine': 16.8293618,
#    'business_info': 'Mo-Sa 09:00-21:00; Su 10:00-21:00',
#    'accessibility': 'yes 1',
#    'location_info': '1',
#    'services': 'yes'},
#   {'Spazio': 'Tesori domani Sicilia',
#    'Categoria': 'cafe',
#    'latitudine': 41.1235735,
#    'longitudine': 16.8686645,
#    'address': 'Via Andrea da Bari 79 70122',
#    'contact': '+39 0805236101',
#    'business_info': 'M. & M. Srlsu'},
#   {'Spazio': 'Vavì',
#    'Categoria': 'cafe',
#    'latitudine': 41.1218665,
#    'longitudine': 16.8792891},
#   {'Spazio': 'Caffè del Borgo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1283925,
#    'longitudine': 16.8683763,
#    'address': "Piazza dell'Odegitria 5 Bari",
#    'business_info': 'Ar. Gio s.r.l.s.',
#    'services': 'no'},
#   {'Spazio': 'Bacio di Latte Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1251144,
#    'longitudine': 16.8692524,
#    'address': 'Via Sparano da Bari 25/a 70122 Bari',
#    'contact': '+39 0805234177 http://www.baciodilattebari.it/',
#    'business_info': '07:00-21:00',
#    'accessibility': 'yes'},
#   {'Spazio': 'Jérôme Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.124141,
#    'longitudine': 16.8692049,
#    'address': 'Via Alessandro Maria Calefati 61b 70121 Bari',
#    'contact': '+39 0805212525'},
#   {'Spazio': 'Caffè Cognetti',
#    'Categoria': 'cafe',
#    'latitudine': 41.1224965,
#    'longitudine': 16.8698103,
#    'address': 'Via Sparano da Bari 120 70121 Bari',
#    'contact': '+39 0809260733 https://www.caffecognetti.com/'},
#   {'Spazio': 'Caffè Vergnano 1882',
#    'Categoria': 'cafe',
#    'latitudine': 41.1216231,
#    'longitudine': 16.869873,
#    'address': 'Via Sparano da Bari 150 70121 Bari'},
#   {'Spazio': 'Tiffany Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1218656,
#    'longitudine': 16.87047,
#    'address': 'Via Argiro 137 70121 Bari',
#    'contact': '+39 0805232447 https://www.tiffanycaffe.com/'},
#   {'Spazio': 'Jérôme Bakery',
#    'Categoria': 'cafe',
#    'latitudine': 41.1192267,
#    'longitudine': 16.8700978,
#    'address': 'Via Sparano da Bari 178 70121 Bari',
#    'contact': '+39 080 975 3071 https://jeromebakery.it/'},
#   {'Spazio': 'Bar Adua',
#    'Categoria': 'cafe',
#    'latitudine': 41.0878459,
#    'longitudine': 16.9970243},
#   {'Spazio': 'Bistrot Brasil',
#    'Categoria': 'cafe',
#    'latitudine': 41.128917,
#    'longitudine': 16.8708536},
#   {'Spazio': 'Saicaf Il Caffé',
#    'Categoria': 'cafe',
#    'latitudine': 41.1259186,
#    'longitudine': 16.8700645,
#    'address': 'Via Argiro 1 70122 Bari',
#    'contact': 'https://www.saicaf.it/'},
#   {'Spazio': 'Semplice Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1250035,
#    'longitudine': 16.8704343,
#    'address': 'Via Argiro 32 70122 Bari',
#    'contact': '+39 080 573 9071 https://www.semplicecafe.it/',
#    'business_info': 'Mo-Sa 07:00-22:30; Su 08:00-22:30',
#    'services': 'yes'},
#   {'Spazio': 'Rosalba cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.0969364,
#    'longitudine': 16.8550728,
#    'address': 'Via Camillo Rosalba 49A 70124 Bari',
#    'contact': '+39 0805618471'},
#   {'Spazio': 'Jérôme Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1236739,
#    'longitudine': 16.8705695,
#    'address': 'Via Argiro 74 70121 Bari',
#    'contact': '+39 0805215211'},
#   {'Spazio': 'Se Ti Va',
#    'Categoria': 'cafe',
#    'latitudine': 41.123882,
#    'longitudine': 16.8705504,
#    'address': 'Via Argiro 64 70121 Bari',
#    'contact': '+39 3293332016',
#    'services': 'yes'},
#   {'Spazio': 'Café Murat',
#    'Categoria': 'cafe',
#    'latitudine': 41.1232568,
#    'longitudine': 16.8706048,
#    'address': 'Via Argiro 88 70121 Bari',
#    'contact': '+39 0802049109'},
#   {'Spazio': 'Serafina Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1228882,
#    'longitudine': 16.8703656,
#    'address': 'Via Argiro 105 70121 Bari',
#    'contact': '+39 3209672960'},
#   {'Spazio': 'Fuwa',
#    'Categoria': 'cafe',
#    'latitudine': 41.122447,
#    'longitudine': 16.8704273,
#    'address': 'Via Argiro 119 70121 Bari',
#    'contact': 'https://www.instagram.com/fuwa_bari/'},
#   {'Spazio': 'Bar Giotì',
#    'Categoria': 'cafe',
#    'latitudine': 41.1203073,
#    'longitudine': 16.8589768},
#   {'Spazio': 'Caffè Portineria',
#    'Categoria': 'cafe',
#    'latitudine': 41.1241993,
#    'longitudine': 16.8682278,
#    'address': 'Via Roberto da Bari 58A 70122 Bari',
#    'contact': '+39 3517204482 info@caffeportineria.it https://www.caffèportineria.it'},
#   {'Spazio': 'Caffè Vanity',
#    'Categoria': 'cafe',
#    'latitudine': 41.1252131,
#    'longitudine': 16.8712815,
#    'address': 'Via Melo da Bari 28 70122 Bari',
#    'contact': '+39 0805212265'},
#   {'Spazio': 'Glamour Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1243719,
#    'longitudine': 16.8710992,
#    'address': 'Via Melo da Bari 57 70121 Bari',
#    'contact': '+39 0803215895'},
#   {'Spazio': 'Mozart Caffé',
#    'Categoria': 'cafe',
#    'latitudine': 41.1219103,
#    'longitudine': 16.8713624,
#    'address': 'Via Melo da Bari 139 70121 Bari',
#    'contact': '+39 0805245015'},
#   {'Spazio': 'Floro in Centro',
#    'Categoria': 'cafe',
#    'latitudine': 41.1258324,
#    'longitudine': 16.8684429,
#    'address': 'Corso Vittorio Emanuele Secondo 74 70122 Bari',
#    'contact': '+39 0805679290 pasticceriafloro@libero.it https://www.pasticceriafloro.com/'},
#   {'Spazio': 'Black Lounge Bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1255207,
#    'longitudine': 16.8630281,
#    'address': 'Corso Vittorio Emanuele Secondo 182 70123 Bari',
#    'contact': '+39 0808642695 https://www.blackloungebar.com/'},
#   {'Spazio': 'Pausa Caffè Caffetteria',
#    'Categoria': 'cafe',
#    'latitudine': 41.1260129,
#    'longitudine': 16.8714587,
#    'address': 'Corso Vittorio Emanuele Secondo 16 70122 Bari'},
#   {'Spazio': 'Bar Sayonara',
#    'Categoria': 'cafe',
#    'latitudine': 41.1192524,
#    'longitudine': 16.8706133,
#    'address': '18 70122 Bari Piazza Aldo Moro'},
#   {'Spazio': 'Cafe-Bar Georgia',
#    'Categoria': 'cafe',
#    'latitudine': 41.1224997,
#    'longitudine': 16.8607734,
#    'business_info': '2022'},
#   {'Spazio': 'Komodo Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1226141,
#    'longitudine': 16.8668767,
#    'address': 'Via Principe Amedeo 125 70122 Bari',
#    'contact': '+39 3496910600 atricasi@hotmail.com'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1169442,
#    'longitudine': 16.8704668},
#   {'Spazio': 'Albaradan',
#    'Categoria': 'cafe',
#    'latitudine': 41.1622906,
#    'longitudine': 16.7506725,
#    'address': 'Via Napoli in Santo Spirito 43A 70127 Santo Spirito',
#    'accessibility': 'no'},
#   {'Spazio': 'Caffetteria Italia',
#    'Categoria': 'cafe',
#    'latitudine': 41.1631185,
#    'longitudine': 16.7475364,
#    'address': 'Via Napoli in Santo Spirito 70127 Santo Spirito'},
#   {'Spazio': 'Il Gabbiano',
#    'Categoria': 'cafe',
#    'latitudine': 41.1633594,
#    'longitudine': 16.7512074,
#    'address': 'Lungomare Cristoforo Colombo 70127 Bari',
#    'business_info': 'Mo-Su 05:30-00:00',
#    'accessibility': 'no'},
#   {'Spazio': 'Peccati di Gola',
#    'Categoria': 'cafe',
#    'latitudine': 41.1598715,
#    'longitudine': 16.7676791,
#    'address': 'Via Vittorio Veneto in Palese 70128 Palese'},
#   {'Spazio': 'Bar Gemma',
#    'Categoria': 'cafe',
#    'latitudine': 41.1534698,
#    'longitudine': 16.7649449,
#    'address': 'Via Renna 32 70128 Palese'},
#   {'Spazio': 'Manila',
#    'Categoria': 'cafe',
#    'latitudine': 41.1512054,
#    'longitudine': 16.767377,
#    'address': 'Via Amedeo di Savoia 70128 Palese',
#    'accessibility': 'no'},
#   {'Spazio': 'Marea',
#    'Categoria': 'cafe',
#    'latitudine': 41.1631939,
#    'longitudine': 16.7516147,
#    'address': '70127 Santo Spirito'},
#   {'Spazio': 'Caffè Diaz',
#    'Categoria': 'cafe',
#    'latitudine': 41.1532867,
#    'longitudine': 16.7668985,
#    'address': 'Via Armando Diaz 70128 Palese'},
#   {'Spazio': "Benny's Bar",
#    'Categoria': 'cafe',
#    'latitudine': 41.1627791,
#    'longitudine': 16.7482856,
#    'address': 'Via Napoli in Santo Spirito 110 70127 Santo Spirito',
#    'contact': '+39 080 533 5669',
#    'business_info': 'Mo-Su 06:00-23:00',
#    'accessibility': 'limited 0',
#    'location_info': '0'},
#   {'Spazio': 'Exó',
#    'Categoria': 'cafe',
#    'latitudine': 41.1502836,
#    'longitudine': 16.7650106},
#   {'Spazio': 'Bar del Corso',
#    'Categoria': 'cafe',
#    'latitudine': 41.1504455,
#    'longitudine': 16.7647232},
#   {'Spazio': 'Ghiaccio Bollente',
#    'Categoria': 'cafe',
#    'latitudine': 41.1639706,
#    'longitudine': 16.7526497,
#    'address': 'Largo Cristoforo Colombo 20A 70127 Bari',
#    'contact': '+39 342 147 7727',
#    'business_info': 'Mo 06:30-00:00; Tu off; We-Su 06:30-00:00',
#    'services': 'yes'},
#   {'Spazio': 'Caffè Dante',
#    'Categoria': 'cafe',
#    'latitudine': 41.1221011,
#    'longitudine': 16.8694325,
#    'address': 'Via Dante Alighieri 63 70121 Bari'},
#   {'Spazio': 'Bar Ospedale San Paolo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1186307,
#    'longitudine': 16.7813771,
#    'address': 'Strada Capo Scardicchio Bari',
#    'services': 'no'},
#   {'Spazio': 'Bianca Cafe',
#    'Categoria': 'cafe',
#    'latitudine': 41.1226789,
#    'longitudine': 16.870757},
#   {'Spazio': 'Dolce e Salato',
#    'Categoria': 'cafe',
#    'latitudine': 41.1216843,
#    'longitudine': 16.8682833},
#   {'Spazio': 'Aurelio Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1213921,
#    'longitudine': 16.8688612,
#    'address': 'Via Domenico Nicolai 70121 Bari',
#    'business_info': 'Mo-Sa 07:30-20:30; Su 08:30-13:30',
#    'services': 'yes'},
#   {'Spazio': 'Black Lounge bar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1217622,
#    'longitudine': 16.8526747},
#   {'Spazio': 'San Francesco',
#    'Categoria': 'cafe',
#    'latitudine': 41.1222581,
#    'longitudine': 16.8695214,
#    'address': 'Via Sparano da Bari 105'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1509792,
#    'longitudine': 16.753103},
#   {'Spazio': "Stefy's Cathedral Coffee",
#    'Categoria': 'cafe',
#    'latitudine': 41.1287109,
#    'longitudine': 16.8686077,
#    'address': "Piazza dell'Odegitria",
#    'contact': 'https://www.stefyscathedralcoffee.it/'},
#   {'Spazio': 'Caffè Roma',
#    'Categoria': 'cafe',
#    'latitudine': 41.1238267,
#    'longitudine': 16.8686557,
#    'address': 'Via Andrea da Bari 67'},
#   {'Spazio': 'White cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1226487,
#    'longitudine': 16.8550707,
#    'address': 'Via Indipendenza 18 70123',
#    'contact': '+393476506817',
#    'business_info': 'Mo-Sa 07:00-19:30; Su 07:00-13:00'},
#   {'Spazio': 'Mamajuana',
#    'Categoria': 'cafe',
#    'latitudine': 41.1171484,
#    'longitudine': 16.8736733,
#    'address': 'Via Giuseppe Re David'},
#   {'Spazio': 'Conticchio',
#    'Categoria': 'cafe',
#    'latitudine': 41.1161646,
#    'longitudine': 16.8729409,
#    'address': "Viale Unità d'Italia"},
#   {'Spazio': 'Dea cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1169677,
#    'longitudine': 16.8716253},
#   {'Spazio': 'Caffè Vergnano 2 Giugno',
#    'Categoria': 'cafe',
#    'latitudine': 41.1033618,
#    'longitudine': 16.8757996,
#    'address': 'Via della Resistenza'},
#   {'Spazio': 'Crema & Cioccolato',
#    'Categoria': 'cafe',
#    'latitudine': 41.1220024,
#    'longitudine': 16.8680501,
#    'address': 'Via Dante Alighieri',
#    'contact': 'https://www.cremaecioccolato.com/'},
#   {'Spazio': 'Fadi',
#    'Categoria': 'cafe',
#    'latitudine': 41.1212433,
#    'longitudine': 16.8550035,
#    'address': 'Via Dante Alighieri'},
#   {'Spazio': 'Mary',
#    'Categoria': 'cafe',
#    'latitudine': 41.1507871,
#    'longitudine': 16.7620214},
#   {'Spazio': 'Dreambar',
#    'Categoria': 'cafe',
#    'latitudine': 41.1549969,
#    'longitudine': 16.7661507},
#   {'Spazio': 'Piccola Caffetteria',
#    'Categoria': 'cafe',
#    'latitudine': 41.1273057,
#    'longitudine': 16.8512319},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1252918,
#    'longitudine': 16.8482663},
#   {'Spazio': 'Mozart Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1238528,
#    'longitudine': 16.8682535,
#    'business_info': 'Mo-Su 07:00-19:00'},
#   {'Spazio': 'Baretto',
#    'Categoria': 'cafe',
#    'latitudine': 41.1224287,
#    'longitudine': 16.868392},
#   {'Spazio': 'Il Piccolo Cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1615522,
#    'longitudine': 16.7538959,
#    'address': 'Vico Traversa 3'},
#   {'Spazio': 'Caravella',
#    'Categoria': 'cafe',
#    'latitudine': 41.1598052,
#    'longitudine': 16.7372591},
#   {'Spazio': 'Bar Balice',
#    'Categoria': 'cafe',
#    'latitudine': 41.1275128,
#    'longitudine': 16.7593676},
#   {'Spazio': 'Floriano',
#    'Categoria': 'cafe',
#    'latitudine': 41.121966,
#    'longitudine': 16.8674154,
#    'address': 'Via Dante Alighieri'},
#   {'Spazio': 'Dodo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1219101,
#    'longitudine': 16.8663748,
#    'address': 'Via Dante Alighieri',
#    'contact': 'https://dodo-cafe.metro.bar/'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1213876,
#    'longitudine': 16.8654873,
#    'address': 'Via de Rossi'},
#   {'Spazio': 'Crema & Amarena',
#    'Categoria': 'cafe',
#    'latitudine': 41.1588264,
#    'longitudine': 16.7611292,
#    'address': 'Via Napoli in Santo Spirito'},
#   {'Spazio': 'Video Gusto',
#    'Categoria': 'cafe',
#    'latitudine': 41.157735,
#    'longitudine': 16.7679547},
#   {'Spazio': '... Nicole',
#    'Categoria': 'cafe',
#    'latitudine': 41.1237486,
#    'longitudine': 16.8610606,
#    'address': 'Via Alessandro Manzoni'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1669959,
#    'longitudine': 16.7467438,
#    'address': 'Lungomare Cristoforo Colombo 70127',
#    'business_info': 'Lido La Rotonda'},
#   {'Spazio': 'Veronero Caffè',
#    'Categoria': 'cafe',
#    'latitudine': 41.1253986,
#    'longitudine': 16.868929,
#    'address': 'Via Niccolò Piccinni 81 70122 Bari',
#    'contact': 'https://www.veronero.it/'},
#   {'Spazio': 'Napoleon',
#    'Categoria': 'cafe',
#    'latitudine': 41.1214392,
#    'longitudine': 16.8718135,
#    'address': 'Via Antonio Beatillo'},
#   {'Spazio': 'Bar dello Studente',
#    'Categoria': 'cafe',
#    'latitudine': 41.1269413,
#    'longitudine': 16.8644238,
#    'address': "Via San Francesco d'Assisi 35 70122 Bari",
#    'contact': '+39 080 5211516',
#    'business_info': 'Scamarda Maria',
#    'accessibility': 'yes'},
#   {'Spazio': 'Caracolito Coffee Shop',
#    'Categoria': 'cafe',
#    'latitudine': 41.1253778,
#    'longitudine': 16.8668321,
#    'address': 'Via Benedetto Cairoli 15 70122 Bari'},
#   {'Spazio': 'Caffè del Ferrarese',
#    'Categoria': 'cafe',
#    'latitudine': 41.1267912,
#    'longitudine': 16.8717197,
#    'address': 'Piazza del Ferrarese 1 70122 Bari'},
#   {'Spazio': 'White Manhattan',
#    'Categoria': 'cafe',
#    'latitudine': 41.1166994,
#    'longitudine': 16.8674846},
#   {'Spazio': 'Ladisa',
#    'Categoria': 'cafe',
#    'latitudine': 41.1245072,
#    'longitudine': 16.8649828,
#    'address': 'Via Abate Giacinto Gimma 175 70122 Bari'},
#   {'Spazio': 'Bar Martini',
#    'Categoria': 'cafe',
#    'latitudine': 41.1191843,
#    'longitudine': 16.8590882,
#    'address': 'Via Scipione Crisanzio 198 70123 Bari'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1332058,
#    'longitudine': 16.8483713,
#    'location_info': 'yes'},
#   {'Spazio': 'Chiosco Garibaldi',
#    'Categoria': 'cafe',
#    'latitudine': 41.125781,
#    'longitudine': 16.8616432,
#    'address': 'Piazza Giuseppe Garibaldi',
#    'accessibility': 'no',
#    'location_info': 'yes',
#    'services': 'no'},
#   {'Spazio': 'Mami - Caffè e Cucina Tipica',
#    'Categoria': 'cafe',
#    'latitudine': 41.1482455,
#    'longitudine': 16.7846304,
#    'location_info': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.0741245,
#    'longitudine': 16.8711227,
#    'location_info': 'kiosk'},
#   {'Spazio': 'Hyde park cafè',
#    'Categoria': 'cafe',
#    'latitudine': 41.101018,
#    'longitudine': 16.8739738,
#    'location_info': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.0737141,
#    'longitudine': 16.8850665,
#    'location_info': 'yes'},
#   {'Spazio': 'Cafè Movida',
#    'Categoria': 'cafe',
#    'latitudine': 41.0738176,
#    'longitudine': 16.8709599,
#    'location_info': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'cafe',
#    'latitudine': 41.1379387,
#    'longitudine': 16.8234428,
#    'location_info': 'yes'},
#   {'Spazio': 'IL cHiOsCo',
#    'Categoria': 'cafe',
#    'latitudine': 41.1210047,
#    'longitudine': 16.8699718,
#    'address': 'Piazza Umberto Primo 70121 Bari',
#    'location_info': 'yes'},
#   {'Spazio': 'Eni Café',
#    'Categoria': 'cafe',
#    'latitudine': 41.1073894,
#    'longitudine': 16.8209389,
#    'location_info': 'yes'},
#   {'Spazio': 'Carbur Drink Shop',
#    'Categoria': 'cafe',
#    'latitudine': 41.1022112,
#    'longitudine': 16.9254717,
#    'contact': 'https://cds416.wixsite.com/carbur-drink-shop',
#    'location_info': 'yes'},
#   {'Spazio': 'Winning games Slot Italy',
#    'Categoria': 'casino',
#    'latitudine': 41.1569968,
#    'longitudine': 16.7658994},
#   {'Spazio': 'AncheCinema Teatro Polifunzionale',
#    'Categoria': 'cinema',
#    'latitudine': 41.1179704,
#    'longitudine': 16.8642494,
#    'old_name': 'Cinema Teatro Royal',
#    'contact': 'https://www.anchecinema.com/',
#    'business_info': 'AncheCinema s.r.l.',
#    'accessibility': 'yes',
#    'entertainment': '1'},
#   {'Spazio': 'Cinema Esedra',
#    'Categoria': 'cinema',
#    'latitudine': 41.1185756,
#    'longitudine': 16.8832022,
#    'address': 'Largo Monsignore Augusto Curi 19 70121',
#    'contact': 'http://www.cinemaesedra.it/'},
#   {'Spazio': 'Nuovo Splendor',
#    'Categoria': 'cinema',
#    'latitudine': 41.1106541,
#    'longitudine': 16.8699432,
#    'address': 'Via Buccari 24 70125'},
#   {'Spazio': 'ABCinema',
#    'Categoria': 'cinema',
#    'latitudine': 41.1383759,
#    'longitudine': 16.8422523},
#   {'Spazio': 'Sala Cinema Cineporto',
#    'Categoria': 'cinema',
#    'latitudine': 41.1372163,
#    'longitudine': 16.8388862,
#    'business_info': 'Fondazione Apulia Film Commission',
#    'accessibility': 'yes'},
#   {'Spazio': 'Multicinema Galleria',
#    'Categoria': 'cinema',
#    'latitudine': 41.118706,
#    'longitudine': 16.8683224,
#    'address': 'Corso Italia 17 70123 Bari',
#    'contact': '+39 0805214563 https://www.multicinemagalleria.it/',
#    'business_info': 'Mo-Su 15:30-21:30; Sa-Su 10:00-13:00',
#    'entertainment': '8'},
#   {'Spazio': 'Il Piccolo',
#    'Categoria': 'cinema',
#    'latitudine': 41.1629075,
#    'longitudine': 16.7489786,
#    'address': 'Via Giannone de Maioribus 4 70127 Santo Spirito',
# ...
#    'longitudine': 16.8622971,
#    'address': 'Viale Quinto Ennio 84 70124',
#    'contact': '3298468457 https://the-butcher-hamburgeria-bari.it/',
#    'business_info': 'Sa 11:00-00:00; Tu-Fr 11:00-23:00; Su 18:00-00:00'},
#   {'Spazio': 'La Piadineria',
#    'Categoria': 'fast food',
#    'latitudine': 41.1263281,
#    'longitudine': 16.8690319,
#    'brand': 'La Piadineria',
#    'address': 'Corso Vittorio Emanuele Secondo 93 70122 Bari',
#    'contact': 'https://lapiadineria.com/i-nostri-ristoranti/bari-corso-vittorio-emanuele-ii',
#    'business_info': 'Mo-Th 11:00-23:00; Fr-Su 11:00-24:00'},
#   {'Spazio': 'Ristokebab Istanbul',
#    'Categoria': 'fast food',
#    'latitudine': 41.1262864,
#    'longitudine': 16.8713277,
#    'address': 'Corso Vittorio Emanuele Secondo 11 70122 Bari'},
#   {'Spazio': 'Da Tina',
#    'Categoria': 'fast food',
#    'latitudine': 41.16358,
#    'longitudine': 16.7525753,
#    'contact': 'https://www.instagram.com/datina_gastronomia/'},
#   {'Spazio': 'La Baita',
#    'Categoria': 'fast food',
#    'latitudine': 41.0881331,
#    'longitudine': 16.9982441,
#    'address': 'Viale Grotta della Regina',
#    'location_info': 'yes'},
#   {'Spazio': "McDonald's",
#    'Categoria': 'fast food',
#    'latitudine': 41.0990041,
#    'longitudine': 16.8294388,
#    'brand': "McDonald's",
#    'business_info': 'PH,Mo-Su 07:00-02:00',
#    'accessibility': 'yes',
#    'location_info': 'yes',
#    'services': 'wlan'},
#   {'Spazio': "McDonald's",
#    'Categoria': 'fast food',
#    'latitudine': 41.0892764,
#    'longitudine': 16.8957537,
#    'brand': "McDonald's",
#    'contact': '+39 0805484840 https://www.mcdonalds.it/ristorante/puglia/bari/bari-mungivacca',
#    'business_info': 'Mo-Su 08:00-01:00 Mo-Su 08:00-02:00',
#    'location_info': 'yes'},
#   {'Spazio': 'Il Chioschetto',
#    'Categoria': 'fast food',
#    'latitudine': 41.1230301,
#    'longitudine': 16.8609427,
#    'address': 'Via Alessandro Manzoni 73 70122 Bari',
#    'location_info': 'shed'},
#   {'Spazio': "McDonald's",
#    'Categoria': 'fast food',
#    'latitudine': 41.0894103,
#    'longitudine': 16.863743,
#    'brand': "McDonald's",
#    'address': 'Tangenziale di Bari Bari',
#    'business_info': 'Mo-Th 07:00-00:00; Fr-Su 07:00-01:00 Mo 00:00-02:00, 07:00-02:00; Tu-Th 07:00-02:00; Fr 07:00-24:00; Sa-Su 00:00-24:00',
#    'location_info': 'yes'},
#   {'Spazio': "Antico Chiosco da U' Russ",
#    'Categoria': 'fast food',
#    'latitudine': 41.1302496,
#    'longitudine': 16.867954,
#    'location_info': 'kiosk'},
#   {'Spazio': "McDonald's",
#    'Categoria': 'fast food',
#    'latitudine': 41.1247498,
#    'longitudine': 16.821869,
#    'brand': "McDonald's",
#    'contact': '+39 0805343026 https://www.mcdonalds.it/ristorante/puglia/bari/bari-tangenziale',
#    'business_info': 'Mo-Su 07:00-01:00'},
#   {'Spazio': "McDonald's",
#    'Categoria': 'fast food',
#    'latitudine': 41.1318058,
#    'longitudine': 16.8245263,
#    'brand': "McDonald's",
#    'contact': '+39 0802100422 https://www.mcdonalds.it/',
#    'business_info': 'Mo-Su 07:00-01:00 Su-Th 07:00-02:00; Fr-Sa 00:00-00:00',
#    'services': 'wlan'},
#   {'Spazio': 'La cucina itinerante di Lory',
#    'Categoria': 'food court',
#    'latitudine': 41.1676575,
#    'longitudine': 16.7340448,
#    'address': 'Via Caladonia 48 70128 Bari',
#    'contact': '3274359761 https://vymaps.com/IT/La-Cucina-Itinerante-Di-Lory-405345749667803/'},
#   {'Spazio': 'Sandrino',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1274867,
#    'longitudine': 16.8715415,
#    'address': 'Piazza Mercantile 3 70122 Bari',
#    'contact': 'info@gelateriasandrino.it https://www.gelateriesandrino.it/',
#    'accessibility': 'limited'},
#   {'Spazio': 'Il Gelatiere',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1363786,
#    'longitudine': 16.8377459},
#   {'Spazio': 'Gelateria Santa Lucia',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1389638,
#    'longitudine': 16.8412018},
#   {'Spazio': 'Yogood',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1128985,
#    'longitudine': 16.8730165,
#    'address': 'Via Luigi Galvani 6/r 70124 Bari'},
#   {'Spazio': 'Epiko',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1258628,
#    'longitudine': 16.8718131,
#    'address': 'Corso Cavour 9 70122 Bari',
#    'contact': '+39 3889823052 epiko2023@gmail.com',
#    'accessibility': 'no'},
#   {'Spazio': 'Gelateria Gentile',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1279984,
#    'longitudine': 16.8675066,
#    'address': 'Piazza Federico Secondo di Svevia 33'},
#   {'Spazio': 'Gasperini',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1243631,
#    'longitudine': 16.8719788,
#    'address': 'Corso Cavour 55 70121 Bari',
#    'contact': 'https://www.gelateriagasperini.it/'},
#   {'Spazio': 'Gelateria Piccinni',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1252156,
#    'longitudine': 16.8659603,
#    'address': 'Via Niccolò Piccinni 131 70122 Bari',
#    'business_info': 'Mo-Fr 11:00-23:00',
#    'accessibility': 'limited'},
#   {'Spazio': 'Yogo',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1262892,
#    'longitudine': 16.8713843,
#    'address': 'Corso Vittorio Emanuele Secondo 9 70122 Bari',
#    'business_info': 'Mo-Fr 17:00-26:00; Sa 17:00-28:00; Su 17:00-27:00'},
#   {'Spazio': 'Coccolato',
#    'Categoria': 'ice cream',
#    'latitudine': 41.1260185,
#    'longitudine': 16.8715626,
#    'address': 'Corso Vittorio Emanuele Secondo 12 70122 Bari',
#    'contact': '+39 3287354289 icedreamsrls@gmail.com'},
#   {'Spazio': 'Rapalisi Gelateria Argentina',
#    'Categoria': 'ice cream',
#    'latitudine': 41.162628,
#    'longitudine': 16.75118,
#    'address': 'Corso Umberto I 19 70127 Santo Spirito',
#    'business_info': 'Tu 16:00-00:00; We-Sa 08:30-13:00,16:00-00:00; Su 08:30-13:00,16:00-00:00',
#    'accessibility': 'limited',
#    'services': 'no'},
#   {'Spazio': 'Il Chioschetto',
#    'Categoria': 'ice cream',
#    'latitudine': 41.109695,
#    'longitudine': 16.8720776,
#    'location_info': 'shed'},
#   {'Spazio': 'World Connection 2',
#    'Categoria': 'internet cafe',
#    'latitudine': 41.1206569,
#    'longitudine': 16.8713109,
#    'address': 'Via Giuseppe Forges Davanzati 30 70121 Bari'},
#   {'Spazio': None,
#    'Categoria': 'marketplace',
#    'latitudine': 41.1063905,
#    'longitudine': 16.8642506},
#   {'Spazio': 'different shops opened every days',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1049893,
#    'longitudine': 16.8798584},
#   {'Spazio': 'weekly market/mercato settimanale',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1047449,
#    'longitudine': 16.8820609},
#   {'Spazio': 'Mercato del pesce',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1283184,
#    'longitudine': 16.8746695,
#    'accessibility': 'yes'},
#   {'Spazio': 'Mercato Coperto di Via Tanzi',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1186426,
#    'longitudine': 16.875534,
#    'accessibility': '0',
#    'location_info': 'yes 0'},
#   {'Spazio': 'Antiquariando',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1263442,
#    'longitudine': 16.8665163,
#    'business_info': 'Oct-Jun Sa,Su 09:00-21:00 "1st week of the month"'},
#   {'Spazio': 'Mercato di Santa Chiara',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1143902,
#    'longitudine': 16.8882218},
#   {'Spazio': 'Mercato Comunale "San Filippo Neri"',
#    'Categoria': 'marketplace',
#    'latitudine': 41.0737185,
#    'longitudine': 16.8635501,
#    'alt_name': 'Mercato Coperto di Carbonara',
#    'location_info': 'yes'},
#   {'Spazio': 'Mercato coperto',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1079555,
#    'longitudine': 16.8962738,
#    'location_info': 'yes'},
#   {'Spazio': 'Mercato Coperto "Madonna del Carmelo"',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1257335,
#    'longitudine': 16.8525072,
#    'alt_name': 'Mercato Coperto di Corso Mazzini',
#    'address': 'Corso Giuseppe Mazzini',
#    'location_info': 'roof'},
#   {'Spazio': 'Mercato Coperto Ex Manifattura Tabacchi',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1199478,
#    'longitudine': 16.8579846},
#   {'Spazio': 'Mercato Contadino di Bari',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1157716,
#    'longitudine': 16.8809848,
#    'address': 'Via Giovanni Amendola',
#    'location_info': 'yes'},
#   {'Spazio': 'Mercato Santa Scolastica',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1065531,
#    'longitudine': 16.8664736},
#   {'Spazio': 'Mercato coperto di San Girolamo',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1368797,
#    'longitudine': 16.8188249,
#    'business_info': 'Comune di Bari',
#    'location_info': 'yes'},
#   {'Spazio': 'Mercato Settimanale',
#    'Categoria': 'marketplace',
#    'latitudine': 41.1291451,
#    'longitudine': 16.8400145},
#   {'Spazio': 'Mercato Settimanale',
#    'Categoria': 'marketplace',
#    'latitudine': 41.0739025,
#    'longitudine': 16.8627278,
#    'business_info': 'Tu 6:00-16:00'},
#   {'Spazio': None,
#    'Categoria': 'nightclub',
#    'latitudine': 41.1259857,
#    'longitudine': 16.8729705},
#   {'Spazio': 'Kabuki',
#    'Categoria': 'nightclub',
#    'latitudine': 41.1194921,
#    'longitudine': 16.8664488,
#    'address': 'Piazzetta dei Frati Cappuccini 1 70122 Bari',
#    'contact': '+39 3515063856'},
#   {'Spazio': 'NOVA Club Culture',
#    'Categoria': 'nightclub',
#    'latitudine': 41.0872624,
#    'longitudine': 16.8958737},
#   {'Spazio': 'Il Fafarulo',
#    'Categoria': 'pub',
#    'latitudine': 41.1053996,
#    'longitudine': 16.8617418},
#   {'Spazio': 'Tropicana Caribbean Pub',
#    'Categoria': 'pub',
#    'latitudine': 41.1161123,
#    'longitudine': 16.8618772,
#    'address': 'Via Giuseppe Albanese',
#    'services': 'wlan'},
#   {'Spazio': 'Nordwind',
#    'Categoria': 'pub',
#    'latitudine': 41.1084634,
#    'longitudine': 16.8860171},
#   {'Spazio': 'Crossroad Saloon',
#    'Categoria': 'pub',
#    'latitudine': 41.1003539,
#    'longitudine': 16.8848843},
#   {'Spazio': 'Stuart',
#    'Categoria': 'pub',
#    'latitudine': 41.1189308,
#    'longitudine': 16.8862824,
#    'services': 'wlan no'},
#   {'Spazio': 'Taverna Vecchia del Maltese',
#    'Categoria': 'pub',
#    'latitudine': 41.1227294,
#    'longitudine': 16.8524108,
#    'accessibility': 'limited'},
#   {'Spazio': 'Bourbon Street',
#    'Categoria': 'pub',
#    'latitudine': 41.1165341,
#    'longitudine': 16.8643811,
#    'business_info': 'Nicola Pignataro'},
#   {'Spazio': 'Flying Circus',
#    'Categoria': 'pub',
#    'latitudine': 41.1291451,
#    'longitudine': 16.8714511},
#   {'Spazio': 'Oktoberfest',
#    'Categoria': 'pub',
#    'latitudine': 41.0981688,
#    'longitudine': 16.8513618,
#    'address': 'Via Giuseppe Posca 59 70124 Bari',
#    'contact': '+39 3482655171 https://www.facebook.com/oktoberbari',
#    'services': 'no'},
#   {'Spazio': None,
#    'Categoria': 'pub',
#    'latitudine': 41.1116828,
#    'longitudine': 16.8911759},
#   {'Spazio': 'Storie del Vecchio Sud',
#    'Categoria': 'pub',
#    'latitudine': 41.1131195,
#    'longitudine': 16.8706468,
#    'address': 'Via Buccari 120 Bari',
#    'business_info': 'Mo-Sa 20:00-01:00, Aug off local knowledge',
#    'services': 'no'},
#   {'Spazio': 'La Taverna del Maltese',
#    'Categoria': 'pub',
#    'latitudine': 41.1212599,
#    'longitudine': 16.8663622,
#    'alt_name': 'Taverna Nuova',
#    'accessibility': '0',
#    'location_info': '0'},
#   {'Spazio': 'Blu eyes',
#    'Categoria': 'pub',
#    'latitudine': 41.1150131,
#    'longitudine': 16.8743534,
#    'address': 'Via Francesco Muciaccia 8 70125 Bari',
#    'business_info': 'Mo-Sa 12:30-15:30,20:00-00:00; Tu off; Su 12:30-15:30,20:00-24:00'},
#   {'Spazio': 'Il Pellicano',
#    'Categoria': 'pub',
#    'latitudine': 41.0949298,
#    'longitudine': 16.8774328},
#   {'Spazio': None,
#    'Categoria': 'pub',
#    'latitudine': 41.1029789,
#    'longitudine': 16.8783301},
#   {'Spazio': 'Bilabì',
#    'Categoria': 'pub',
#    'latitudine': 41.1057339,
#    'longitudine': 16.8798958,
#    'address': 'Via Omodeo 12',
#    'contact': '+39 0808976081'},
#   {'Spazio': 'ekoiné',
#    'Categoria': 'pub',
#    'latitudine': 41.1077125,
#    'longitudine': 16.8637537,
#    'address': 'Via Antonio De Ferraris 49b',
#    'business_info': 'EKO s.a.s. di Fabio Bellucci'},
#   {'Spazio': 'Noise',
#    'Categoria': 'pub',
#    'latitudine': 41.1158465,
#    'longitudine': 16.8646588,
#    'address': 'Viale Antonio Salandra 8a 70124',
#    'business_info': 'Antonio Marzio'},
#   {'Spazio': 'Windigo Saloon',
#    'Categoria': 'pub',
#    'latitudine': 41.1025837,
#    'longitudine': 16.8581635,
#    'address': 'Via Mauro Amoruso 33',
#    'contact': '+39 347 6440575',
#    'business_info': '24/7'},
#   {'Spazio': None,
#    'Categoria': 'pub',
#    'latitudine': 41.1132309,
#    'longitudine': 16.8723204},
#   {'Spazio': 'Fix It Live',
#    'Categoria': 'pub',
#    'latitudine': 41.1118392,
#    'longitudine': 16.8776393,
#    'address': 'Via Quarto 10'},
#   {'Spazio': 'drops',
#    'Categoria': 'pub',
#    'latitudine': 41.1121498,
#    'longitudine': 16.8637088,
#    'address': 'Piazza Giulio Cesare 28 70124',
#    'business_info': 'BOX 28 s.n.c. di Minafra V. e De Tullio G.'},
#   {'Spazio': 'Dexter',
#    'Categoria': 'pub',
#    'latitudine': 41.0882481,
#    'longitudine': 16.8649861,
#    'contact': 'http://www.dexterpub.it'},
#   {'Spazio': 'Keller',
#    'Categoria': 'pub',
#    'latitudine': 41.0941757,
#    'longitudine': 16.865395,
#    'address': 'Via Aurelio Carrante Bari IT',
#    'business_info': 'Keller-fapfap s.a.s.'},
#   {'Spazio': 'Gramigna',
#    'Categoria': 'pub',
#    'latitudine': 41.1104662,
#    'longitudine': 16.8707466},
#   {'Spazio': 'Terzo Tempo',
#    'Categoria': 'pub',
#    'latitudine': 41.1126135,
#    'longitudine': 16.8730498},
#   {'Spazio': "Joy's Shop",
#    'Categoria': 'pub',
#    'latitudine': 41.1190728,
#    'longitudine': 16.8831116},
#   {'Spazio': '1986 Pubsteria Pugliese',
#    'Categoria': 'pub',
#    'latitudine': 41.1250352,
#    'longitudine': 16.8659798,
#    'address': 'Via Niccolò Piccinni 148 70122 Bari IT'},
#   {'Spazio': 'Terra di Mezzo',
#    'Categoria': 'pub',
#    'latitudine': 41.1144488,
#    'longitudine': 16.8799486,
#    'address': 'Via Giovanni Amendola 133 70126 Bari',
#    'contact': 'https://www.pubterradimezzo.it/',
#    'accessibility': 'limited',
#    'services': 'yes'},
#   {'Spazio': None,
#    'Categoria': 'pub',
#    'latitudine': 41.0905439,
#    'longitudine': 16.889165},
#   {'Spazio': 'Canarute',
#    'Categoria': 'pub',
#    'latitudine': 41.1280209,
#    'longitudine': 16.8722504,
#    'address': 'Piazza Mercantile 69',
#    'accessibility': '0',
#    'location_info': '0'},
#   {'Spazio': 'La Farmacia dei Sani',
#    'Categoria': 'pub',
#    'latitudine': 41.1229074,
#    'longitudine': 16.8683594,
#    'address': 'Via Roberto da Bari 104 70122 Bari',
#    'contact': '+39 0805282944 farmaciadeisani@live.it',
#    'business_info': 'Mo-Fr 12:30-14:30, 19:30-24:00'},
#   {'Spazio': 'La Ciclatera',
#    'Categoria': 'pub',
#    'latitudine': 41.1270821,
#    'longitudine': 16.8697074,
#    'address': 'Strada Angiola 23 70122 Bari',
#    'contact': '+39 0805289368 https://laciclatera.eatbu.com/'},
#   {'Spazio': 'Jerusalem',
#    'Categoria': 'pub',
#    'latitudine': 41.1165115,
#    'longitudine': 16.8637024},
#   {'Spazio': 'Berravia',
#    'Categoria': 'pub',
#    'latitudine': 41.1638765,
#    'longitudine': 16.7525856,
#    'address': 'Largo Cristoforo Colombo 22 70127 Bari',
#    'contact': '+39 348 549 1311',
#    'business_info': 'Tu-Fr 18:00-25:00; Sa-Su 11:00-13:30'},
#   {'Spazio': 'Taboo',
#    'Categoria': 'pub',
#    'latitudine': 41.1636661,
#    'longitudine': 16.7526381,
#    'address': 'Lungomare Cristoforo Colombo 36 70127 Santo Spirito',
#    'contact': 'https://www.facebook.com/taboospeakeasy/'},
#   {'Spazio': 'Sun',
#    'Categoria': 'pub',
#    'latitudine': 41.1633693,
#    'longitudine': 16.7496518,
#    'address': 'Lungomare Cristoforo Colombo 142 70127 Santo Spirito'},
#   {'Spazio': 'Fuori Orario',
#    'Categoria': 'pub',
#    'latitudine': 41.1480012,
#    'longitudine': 16.7404467,
#    'address': '1 70127 San Pio Piazzetta Eleonora',
#    'contact': 'https://www.instagram.com/fuoriorariobirrificio/',
#    'business_info': '2023-05-26'},
#   {'Spazio': 'Fermento - Beershop',
#    'Categoria': 'pub',
#    'latitudine': 41.1064301,
#    'longitudine': 16.8777082,
#    'location_info': 'yes'},
#   {'Spazio': 'Timeout - Play Around Food',
#    'Categoria': 'pub',
#    'latitudine': 41.0896244,
#    'longitudine': 16.8833894,
#    'contact': '+39 3896954338 info@timeoutsteakhouse.it https://www.timeoutpub.it/'}])

# %%
traduzioni = {
    'arts centre': 'Centro culturale',
    'bar': 'Bar',
    'cafe': 'Caffè',
    'casino': 'Casinò',
    'cinema': 'Cinema',
    'community centre': 'Centro sociale',
    'events venue': 'Sede eventi',
    'fast food': 'Fast food',
    'food court': 'Area ristorazione',
    'ice cream': 'Gelateria',
    'internet cafe': 'Internet café',
    'marketplace': 'Mercato',
    'monastery': 'Monastero',
    'nightclub': 'Discoteca',
    'place of worship': 'Luogo di culto',
    'pub': 'Pub',
    'restaurant': 'Ristorante',
    'music venue': 'Locale musicale',
    'social centre': 'Centro sociale',
}

# Per applicare le traduzioni ai tuoi dati:
for x in result:
    x["Categoria"] = traduzioni.get(x["Categoria"], x["Categoria"])

# %%
with open ("Amenities.json", "w", encoding='utf-8') as f:
    json.dump(result, f, indent=4, ensure_ascii=False)
